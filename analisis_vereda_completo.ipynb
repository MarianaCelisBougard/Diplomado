# %% [markdown]
# <a href="https://colab.research.google.com/github/MarianaCelisBougard/Diplomado/blob/desarrollo/analisis_vereda_completo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/Clase-Python-USTA/parcial-vereda-CelisBougard.git
# Out:
# fatal: destination path 'parcial-vereda-CelisBougard' already exists and is not an empty directory.

# %%
import os
import unicodedata
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from scipy.stats import chi2_contingency

BASE = Path(".")
DATOS = BASE / "datos"
RESULTADOS = BASE / "resultados"
RESULTADOS.mkdir(parents=True, exist_ok=True)

excel_path = DATOS / "Dat_Ri_Fa_123.xlsx"
df = pd.read_excel(excel_path)
print("Datos cargados:", df.shape)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3213427307.py in <cell line: 0>()
#      13
#      14 excel_path = DATOS / "Dat_Ri_Fa_123.xlsx"
# ---> 15 df = pd.read_excel(excel_path)
#      16 print("Datos cargados:", df.shape)
#      17 df.head()
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# ...

# %%
# === 1. Caracterización Simple ===
print("=== Información básica ===")
print(f"Filas: {df.shape[0]}, Columnas: {df.shape[1]}")
resumen_columnas = pd.DataFrame({
    "tipo": df.dtypes.astype(str),
    "faltantes": df.isna().sum()
})
resumen_columnas.to_csv(RESULTADOS / "resumen_columnas.csv", encoding="utf-8-sig")
resumen_columnas.head()
# Out:
# === Información básica ===
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4036095078.py in <cell line: 0>()
#       1 # === 1. Caracterización Simple ===
#       2 print("=== Información básica ===")
# ----> 3 print(f"Filas: {df.shape[0]}, Columnas: {df.shape[1]}")
#       4 resumen_columnas = pd.DataFrame({
#       5     "tipo": df.dtypes.astype(str),
#
# NameError: name 'df' is not defined
