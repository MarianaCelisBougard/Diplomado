# %%
# ===================================================================
# PASO 1: CONFIGURACIÓN E INSTALACIÓN DE LIBRERÍAS
# ===================================================================

import pandas as pd
import requests
import sqlite3

print("✅ Librerías importadas.")

# ===================================================================
# PASO 2: EXTRACCIÓN (EXTRACT) DE LOS DATOS
# ===================================================================

# La plataforma datos.gov.co usa la API de Socrata. Podemos usarla para
# descargar los datos directamente, lo que es más eficiente que bajar un CSV.
# Aumentamos el límite para traer más filas (ajusta si es necesario).
api_url = "https://www.datos.gov.co/resource/rpmr-utcd.json?$limit=1000000"

print(f"📥 Extrayendo datos desde: {api_url}")

try:
    response = requests.get(api_url)
    response.raise_for_status()  # Lanza un error si la petición falla (ej: 404)
    data = response.json()
    df_raw = pd.DataFrame(data)
    print(f"✅ ¡Extracción exitosa! Se cargaron {len(df_raw)} filas.")
    display(df_raw.head())

except requests.exceptions.RequestException as e:
    print(f"❌ Error al extraer los datos: {e}")
    df_raw = pd.DataFrame() # Creamos un dataframe vacío para evitar errores posteriores

except Exception as e:
    print(f"❌ Ocurrió un error inesperado: {e}")
    df_raw = pd.DataFrame()
# Out:
# ✅ Librerías importadas.
# 📥 Extrayendo datos desde: https://www.datos.gov.co/resource/rpmr-utcd.json?$limit=1000000
# ✅ ¡Extracción exitosa! Se cargaron 1000000 filas.
#   nivel_entidad codigo_entidad_en_secop  \
# 0   TERRITORIAL               205001073
# 1   TERRITORIAL               205001073
# 2   TERRITORIAL               205001073
# 3   TERRITORIAL               205001073
# 4   TERRITORIAL               205001073
#
#                                 nombre_de_la_entidad nit_de_la_entidad  \
# 0  ANTIOQUIA - INSTITUTO TECNOLÓGICO METROPOLITAN...         800214750
# 1  ANTIOQUIA - INSTITUTO TECNOLÓGICO METROPOLITAN...         800214750
# 2  ANTIOQUIA - INSTITUTO TECNOLÓGICO METROPOLITAN...         800214750
# 3  ANTIOQUIA - INSTITUTO TECNOLÓGICO METROPOLITAN...         800214750
# 4  ANTIOQUIA - INSTITUTO TECNOLÓGICO METROPOLITAN...         800214750
#
#   departamento_entidad municipio_entidad estado_del_proceso  \
# 0            Antioquia          Medellín          Liquidado
# 1            Antioquia          Medellín          Liquidado
# 2            Antioquia          Medellín          Liquidado
# 3            Antioquia          Medellín          Liquidado
# 4            Antioquia          Medellín          Liquidado
#
#                  modalidad_de_contrataci_n  \
# 0  Contratación Directa (Ley 1150 de 2007)
# 1  Contratación Directa (Ley 1150 de 2007)
# 2  Contratación Directa (Ley 1150 de 2007)
# 3  Contratación Directa (Ley 1150 de 2007)
# 4  Contratación Directa (Ley 1150 de 2007)
#
#                                   objeto_a_contratar  \
# 0  PRESTACION DE SERVICIOS POR SU PROPIA CUENTA Y...
# 1  PRESTACION DE SERVICIOS POR SU PROPIA CUENTA Y...
# 2  PRESTACION DE SERVICIOS POR SU PROPIA CUENTA Y...
# 3  PRESTACION DE SERVICIOS POR SU PROPIA CUENTA Y...
# 4  PRESTACION DE SERVICIOS POR SU PROPIA CUENTA Y...
#
#                                   objeto_del_proceso  ...  \
# 0  PRESTACIoN DE SERVICIOS POR SU PROPIA CUENTA Y...  ...
# 1  PRESTACIoN DE SERVICIOS POR SU PROPIA CUENTA Y...  ...
# 2  PRESTACIoN DE SERVICIOS POR SU PROPIA CUENTA Y...  ...
# 3  PRESTACIoN DE SERVICIOS POR SU PROPIA CUENTA Y...  ...
# 4  PRESTACIoN DE SERVICIOS POR SU PROPIA CUENTA Y...  ...
#
#     fecha_inicio_ejecuci_n      fecha_fin_ejecuci_n numero_del_contrato  \
# 0  2015-01-16T00:00:00.000  2015-07-15T00:00:00.000       15-12-3326869
# 1  2015-01-16T00:00:00.000  2015-07-15T00:00:00.000       15-12-3327223
# 2  2015-01-16T00:00:00.000  2015-07-15T00:00:00.000       15-12-3327248
# 3  2015-01-16T00:00:00.000  2015-07-15T00:00:00.000       15-12-3327278
# 4  2015-01-16T00:00:00.000  2015-07-15T00:00:00.000       15-12-3327313
#
#   numero_de_proceso valor_contrato         nom_raz_social_contratista  \
# 0   P - 220 de 2015        4996992      KATERIN ELIANA LONDONO TAMAYO
# 1   P - 221 de 2015        4996992        JENIFFER RODRIGUEZ PANIAGUA
# 2   P - 223 de 2015        4996992            TATIANA ACEVEDO ALVAREZ
# 3   P - 225 de 2015        4996992               MARIANA ARANGO LOPEZ
# 4   P - 227 de 2015        4996992  CRISTIAN FELIPE PANIAGUA MARTINEZ
#
#                                         url_contrato  origen  \
# 0  https://www.contratos.gov.co/consultas/detalle...  SECOPI
# 1  https://www.contratos.gov.co/consultas/detalle...  SECOPI
# 2  https://www.contratos.gov.co/consultas/detalle...  SECOPI
# 3  https://www.contratos.gov.co/consultas/detalle...  SECOPI
# 4  https://www.contratos.gov.co/consultas/detalle...  SECOPI
#
#   tipo_documento_proveedor          documento_proveedor
# 0   Nit de Persona Natural     1.020.462.172-4 DE BELLO
# 1   Nit de Persona Natural     1.020.468.804-8 DE BELLO
# 2   Nit de Persona Natural  1.033.176.881-9 DE MEDELLIN
# 3   Nit de Persona Natural   1.035.229.025-7 DE BARBOSA
# 4   Nit de Persona Natural    1.036.650.260-9 DE ITAGUI
#
# [5 rows x 22 columns]
